# %%
import pandas as pd
import numpy as np

# %%
# 读取对测试集的预测。测试集的规模14627。
model_label_pred_label = pd.read_pickle('../data_20220831/model_label_pred_label.pkl')
# model_label_pred_label[(model_label_pred_label['model_label']==1)&(model_label_pred_label['pred_label']==0)]

model_label_pred_label
# Out:
#                                   cv_id                             jd_id  \
# 0      2c9207157ef7ed7f017efd02e21e4e49  2c9207157d2f0ec5017d5a7504c72f8b
# 1      2c920715802399a801804bdec5c34543  2c920715800e886301801791ef1b53ee
# 2      2c92071581c8d04f0181cb3aa9f4639c  2c92071581c8c61e0181cc4416582615
# 3      2c920715802399a801804ba70b163677  2c920715800e886301801791ef1b53ee
# 4      2c92071580b3a89c0180d1cdb36c3c4b  2c920715816798cb01817f99f0341751
# ...                                 ...                               ...
# 14622  2c92071581d380c20181ede1f6b4401f  2c92071581d380a00181dccc2ac54686
# 14623  2c9207157dec317f017e0e75e24d4ab8  2c9207157dec2c34017e05671af21551
# 14624  2c92071581d380c20181d7a76b390856  2c92071581cdd33b0181d224cbdf7b06
# 14625  2c920715816798dd01816b5b135e64b2  2c9207158114fb29018148007d475ade
# 14626  2c92071580f6d9840180f8d5ca77274a  2c92071580f6d9350180f8da1f1c57ef
#
#        model_label  pred_label         0         1
# ...

# %%
# 对列进行重命名
model_label_pred_label = model_label_pred_label.rename(columns={'model_label': 'real_label', 0: 'prob_0', 1: 'prob_1'})
model_label_pred_label
# Out:
#                                   cv_id                             jd_id  \
# 0      2c9207157ef7ed7f017efd02e21e4e49  2c9207157d2f0ec5017d5a7504c72f8b
# 1      2c920715802399a801804bdec5c34543  2c920715800e886301801791ef1b53ee
# 2      2c92071581c8d04f0181cb3aa9f4639c  2c92071581c8c61e0181cc4416582615
# 3      2c920715802399a801804ba70b163677  2c920715800e886301801791ef1b53ee
# 4      2c92071580b3a89c0180d1cdb36c3c4b  2c920715816798cb01817f99f0341751
# ...                                 ...                               ...
# 14622  2c92071581d380c20181ede1f6b4401f  2c92071581d380a00181dccc2ac54686
# 14623  2c9207157dec317f017e0e75e24d4ab8  2c9207157dec2c34017e05671af21551
# 14624  2c92071581d380c20181d7a76b390856  2c92071581cdd33b0181d224cbdf7b06
# 14625  2c920715816798dd01816b5b135e64b2  2c9207158114fb29018148007d475ade
# 14626  2c92071580f6d9840180f8d5ca77274a  2c92071580f6d9350180f8da1f1c57ef
#
#        real_label  pred_label    prob_0    prob_1
# ...

# %%
model_label_pred_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14627 entries, 0 to 14626
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   cv_id       14627 non-null  object
#  1   jd_id       14627 non-null  object
#  2   real_label  14627 non-null  int64
#  3   pred_label  14627 non-null  int64
#  4   prob_0      14627 non-null  float64
#  5   prob_1      14627 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 685.8+ KB

# %%
# 看看real_label和pred_label有多少是一样的。算准确率。
real_label = model_label_pred_label['real_label']
pred_label = model_label_pred_label['pred_label']

match_num = 0
for i,j in zip(real_label, pred_label):
    if i == j:
        match_num += 1
    
match_num
# Out:
# 10892

# %%
'''
INFO:tensorflow:Saving dict for global step 1000: 
accuracy = 0.7446503, accuracy_baseline = 0.570657, auc = 0.8170671, auc_precision_recall = 0.773738, 
average_loss = 0.5155848, global_step = 1000, label/mean = 0.429343, loss = 7541.4595, 
precision = 0.73174286, prediction/mean = 0.41370174, recall = 0.6398089
'''
10892/14626
# Out:
# 0.7447012170108027

# %%
# 读取20220831的所有数据
all_data = pd.read_csv('../data_20220831/raw_cvjd_20220831_spark.csv').drop(['Unnamed: 0'], axis=1)
#all_data
# Out:
# /var/folders/99/wft1658s2mv39cv4wj_rcpqh0000gp/T/ipykernel_1692/4294719399.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_data = pd.read_csv('../data_20220831/raw_cvjd_20220831_spark.csv').drop(['Unnamed: 0'], axis=1)

# %%
all_data.columns
# Out:
# Index(['cv_id', 'jd_id', 'jd_code', 'title', 'deadline', 'category_id',
#        'category_name', 'company_id', 'company_name', 'recruit_number',
#        'work_age', 'min_annual_salary', 'max_annual_salary',
#        'min_month_salary', 'max_month_salary', 'pay_months', 'created_by_name',
#        'created_by', 'created_at', 'updated_by', 'updated_at', 'tenant_id',
#        'guarantee_period', 'status', 'recommended_rcn', 'tags', 'workplaces',
#        'description', 'school', 'degree', 'post_level_id', 'requirement', 'ds',
#        '_id', 'additionInfo', 'age', 'certificates', 'code', 'competenceScore',
#        'completeness', 'countryCode', 'createdAt', 'createdBy',
#        'currentCompany', 'currentPosition', 'currentSalary', 'dateOfBirth',
#        'degree.1', 'desiredIndustry', 'desiredPosition', 'desiredSalary',
#        'dutyTime', 'expectLocation', 'gender', 'importType', 'industry',
#        'interviewTime', 'jobIntentStatus', 'languageSkills', 'languages',
# ...

# %%
all_data
# Out:
#                                   cv_id                             jd_id  \
# 0      2c9207157bf91042017c0d2beef00470  2c9207157bcbb76b017bcde2b46d04cd
# 1      2c9207157bf91042017c0d979cbb047d  2c9207157bcbb76b017bf7f2bbbb3153
# 2      2c9207157bf91042017c7232fbab3be1  2c9207157bf94d99017c108f769405e0
# 3      2c9207157d308592017d4a94cb1113a1  2c9207157d2f0ec5017d5a9265ba33d9
# 4      2c9207157dabb0a3017dbca16cdf4c26  2c9207157d631abb017d6eed1c79139f
# ...                                 ...                               ...
# 83296  8a69f60582c8626e0182c9fc367050e6  8a69c4df82b081d30182c391c1f51bfc
# 83297  8a69f60582c8626e0182cedb7ca86dc8  8a69c47b82b07fdc0182b3dcd51b7a71
# 83298  8a69f61382b080760182c37a984f3a9a  2c92071580dd3ab70180f18714e119c0
# 83299  8a69f64782e59cc90182f37791dc6649  8a69d77e82926b410182b011869b3b74
# 83300  8a69f68b827cca09018284d2bd4d2958  2c92071581900df301819064f39848b3
#
#                       jd_code                 title               deadline  \
# ...

# %%
all_data['cv_id'][0].__class__
# Out:
# str

# %%
# 对all_data进行去重。83301-->82333。去重后的数据规模符合预期。
all_data = all_data.drop_duplicates(subset=['cv_id', 'jd_id'], keep='first')
all_data
# Out:
#                                   cv_id                             jd_id  \
# 0      2c9207157bf91042017c0d2beef00470  2c9207157bcbb76b017bcde2b46d04cd
# 1      2c9207157bf91042017c0d979cbb047d  2c9207157bcbb76b017bf7f2bbbb3153
# 2      2c9207157bf91042017c7232fbab3be1  2c9207157bf94d99017c108f769405e0
# 3      2c9207157d308592017d4a94cb1113a1  2c9207157d2f0ec5017d5a9265ba33d9
# 4      2c9207157dabb0a3017dbca16cdf4c26  2c9207157d631abb017d6eed1c79139f
# ...                                 ...                               ...
# 83296  8a69f60582c8626e0182c9fc367050e6  8a69c4df82b081d30182c391c1f51bfc
# 83297  8a69f60582c8626e0182cedb7ca86dc8  8a69c47b82b07fdc0182b3dcd51b7a71
# 83298  8a69f61382b080760182c37a984f3a9a  2c92071580dd3ab70180f18714e119c0
# 83299  8a69f64782e59cc90182f37791dc6649  8a69d77e82926b410182b011869b3b74
# 83300  8a69f68b827cca09018284d2bd4d2958  2c92071581900df301819064f39848b3
#
#                       jd_code                 title               deadline  \
# ...

# %%
all_data = all_data.reset_index(drop=True)

# %%
# raw_ext_new_feature.join(label_df.set_index(['cv_id', 'jd_id']), on=['cv_id', 'jd_id'], how='inner')

# %%
# 适合抽样检查的jd列
jd_columns = ['title', 'category_name', 'company_name', 'recruit_number', 'work_age',
            'min_annual_salary', 'max_annual_salary', 'min_month_salary', 'max_month_salary', 'pay_months',
            'tags', 'workplaces', 'description', 'school', 'degree', 'requirement']
all_data_jd = all_data[['cv_id', 'jd_id']+jd_columns]

# %%
# 适合抽样检查的cv列
cv_columns = ['additionInfo', 'age', 'gender', 'certificates', 'currentCompany', 'currentPosition', 'desiredPosition',
            'currentSalary', 'desiredSalary', 'degree', 'industry', 'desiredIndustry', 'location', 'expectLocation', 'jobIntentStatus',
            'languageSkills', 'majorName', 'schoolName', 'skills', 'workYear', 'eduTracks', 'jobTracks', 'projectTracks']
all_data_jd = all_data[['cv_id', 'jd_id'] + cv_columns]

# %%
# inner join
# model_label_pred_label all_data_jd all_data_jd
